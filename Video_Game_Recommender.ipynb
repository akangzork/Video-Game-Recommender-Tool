# %%
import pandas as pd
import numpy as np

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Dataset
# Steam Games.csv has over 70,000 games
# Only games with a count of all their reviews are used (about 7% of the data)
# The data is filtered this way in order to reduce the number of data processed and to only have games that are well reviewed by the steam community

# %%
steam_games = pd.read_csv('SteamGames.csv', usecols=['Title','Game Description','Popular Tags','All Reviews Number'])
steam_games = steam_games.drop_duplicates().dropna()
steam_games_tags = steam_games['Popular Tags'].apply(lambda x: x[1:-1].split(','))
games_df = pd.DataFrame({
    'Title': steam_games['Title'],
    'Game Description': steam_games['Game Description'],
    'Popular Tags': steam_games_tags
})

all_genres = pd.DataFrame({'Tags': games_df['Popular Tags'].explode().dropna().unique()});
all_genres = all_genres.drop_duplicates()

print("Number of games to recommend:\t", len(games_df), "\nNumber of different genres:\t", len(all_genres))
# Out:
# Number of games to recommend:	 5371
# Number of different genres:	 732

# %% [markdown]
# # Popular Tags Similarity Matrix

# %%
game_genre_matrix = []
for genres in games_df['Popular Tags']:
    row = [0] * len(all_genres)
    for genre in genres:
      genre_index = all_genres.loc[all_genres['Tags']==genre]
      row[genre_index.index[0]] = 1
    game_genre_matrix.append(row)
game_genre_df = pd.DataFrame(game_genre_matrix, columns=all_genres, index=games_df['Title'])

# %%
tag_similarity = cosine_similarity(game_genre_df)
df_tag_similarity = pd.DataFrame(tag_similarity, columns=games_df['Title'], index=games_df['Title']);
display(df_tag_similarity)
# Out:
# Title                              Baldur's Gate 3  \
# Title
# Baldur's Gate 3                           1.000000
# Counter-Strike: Global Offensive          0.150000
# Apex Legends™                             0.100000
# Forza Horizon 5                           0.200000
# Call of Duty®                             0.200000
# ...                                            ...
# Call of Duty®: Warzone™                   0.200000
# Their Land                                0.250000
# Call of Duty®: Modern Warfare® II         0.200000
# SteamVR                                   0.000000
# Resident Evil 4 Chainsaw Demo             0.091287
#
# Title                              Counter-Strike: Global Offensive  \
# Title
# Baldur's Gate 3                                            0.150000
# Counter-Strike: Global Offensive                           1.000000
# Apex Legends™                                              0.400000
# Forza Horizon 5                                            0.350000
# Call of Duty®                                              0.550000
# ...                                                             ...
# Call of Duty®: Warzone™                                    0.450000
# Their Land                                                 0.200000
# Call of Duty®: Modern Warfare® II                          0.500000
# SteamVR                                                    0.000000
# Resident Evil 4 Chainsaw Demo                              0.091287
#
# Title                              Apex Legends™  Forza Horizon 5  \
# Title
# Baldur's Gate 3                         0.100000         0.200000
# Counter-Strike: Global Offensive        0.400000         0.350000
# Apex Legends™                           1.000000         0.250000
# Forza Horizon 5                         0.250000         1.000000
# Call of Duty®                           0.300000         0.450000
# ...                                          ...              ...
# Call of Duty®: Warzone™                 0.500000         0.600000
# Their Land                              0.300000         0.300000
# Call of Duty®: Modern Warfare® II       0.350000         0.450000
# SteamVR                                 0.000000         0.100000
# Resident Evil 4 Chainsaw Demo           0.182574         0.182574
#
# Title                              Call of Duty®  PUBG: BATTLEGROUNDS  \
# Title
# Baldur's Gate 3                         0.200000             0.200000
# Counter-Strike: Global Offensive        0.550000             0.600000
# Apex Legends™                           0.300000             0.500000
# Forza Horizon 5                         0.450000             0.400000
# Call of Duty®                           1.000000             0.450000
# ...                                          ...                  ...
# Call of Duty®: Warzone™                 0.650000             0.500000
# Their Land                              0.250000             0.250000
# Call of Duty®: Modern Warfare® II       0.850000             0.500000
# SteamVR                                 0.000000             0.100000
# Resident Evil 4 Chainsaw Demo           0.182574             0.091287
#
# Title                              Cyberpunk 2077      Rust  \
# Title
# Baldur's Gate 3                          0.200000  0.150000
# Counter-Strike: Global Offensive         0.100000  0.350000
# Apex Legends™                            0.250000  0.350000
# Forza Horizon 5                          0.350000  0.450000
# Call of Duty®                            0.350000  0.300000
# ...                                           ...       ...
# Call of Duty®: Warzone™                  0.400000  0.500000
# Their Land                               0.300000  0.300000
# Call of Duty®: Modern Warfare® II        0.350000  0.350000
# SteamVR                                  0.000000  0.100000
# Resident Evil 4 Chainsaw Demo            0.273861  0.182574
#
# Title                              Grand Theft Auto V  \
# Title
# Baldur's Gate 3                              0.150000
# Counter-Strike: Global Offensive             0.300000
# Apex Legends™                                0.300000
# Forza Horizon 5                              0.450000
# Call of Duty®                                0.500000
# ...                                               ...
# Call of Duty®: Warzone™                      0.450000
# Their Land                                   0.300000
# Call of Duty®: Modern Warfare® II            0.450000
# SteamVR                                      0.000000
# Resident Evil 4 Chainsaw Demo                0.182574
#
# Title                              Tom Clancy's Rainbow Six® Siege  ...  \
# Title                                                               ...
# Baldur's Gate 3                                           0.150000  ...
# Counter-Strike: Global Offensive                          0.850000  ...
# Apex Legends™                                             0.450000  ...
# Forza Horizon 5                                           0.350000  ...
# Call of Duty®                                             0.550000  ...
# ...                                                            ...  ...
# Call of Duty®: Warzone™                                   0.450000  ...
# Their Land                                                0.250000  ...
# Call of Duty®: Modern Warfare® II                         0.500000  ...
# SteamVR                                                   0.100000  ...
# Resident Evil 4 Chainsaw Demo                             0.091287  ...
#
# Title                              VERGE:Lost chapter  Resident Evil Re:Verse  \
# Title
# Baldur's Gate 3                              0.100000                0.150000
# Counter-Strike: Global Offensive             0.150000                0.200000
# Apex Legends™                                0.250000                0.300000
# Forza Horizon 5                              0.300000                0.400000
# Call of Duty®                                0.400000                0.450000
# ...                                               ...                     ...
# Call of Duty®: Warzone™                      0.350000                0.550000
# Their Land                                   0.300000                0.350000
# Call of Duty®: Modern Warfare® II            0.350000                0.550000
# SteamVR                                      0.100000                0.000000
# Resident Evil 4 Chainsaw Demo                0.365148                0.365148
#
# Title                              HAWKEN REBORN  100 hidden cups  \
# Title
# Baldur's Gate 3                         0.150000         0.050000
# Counter-Strike: Global Offensive        0.200000         0.000000
# Apex Legends™                           0.200000         0.000000
# Forza Horizon 5                         0.200000         0.100000
# Call of Duty®                           0.250000         0.000000
# ...                                          ...              ...
# Call of Duty®: Warzone™                 0.300000         0.050000
# Their Land                              0.300000         0.150000
# Call of Duty®: Modern Warfare® II       0.250000         0.000000
# SteamVR                                 0.100000         0.000000
# Resident Evil 4 Chainsaw Demo           0.182574         0.091287
#
# Title                              O2Jam Online  Call of Duty®: Warzone™  \
# Title
# Baldur's Gate 3                        0.074536                 0.200000
# Counter-Strike: Global Offensive       0.000000                 0.450000
# Apex Legends™                          0.000000                 0.500000
# Forza Horizon 5                        0.074536                 0.600000
# Call of Duty®                          0.074536                 0.650000
# ...                                         ...                      ...
# Call of Duty®: Warzone™                0.074536                 1.000000
# Their Land                             0.074536                 0.350000
# Call of Duty®: Modern Warfare® II      0.074536                 0.700000
# SteamVR                                0.000000                 0.000000
# Resident Evil 4 Chainsaw Demo          0.000000                 0.273861
#
# Title                              Their Land  \
# Title
# Baldur's Gate 3                      0.250000
# Counter-Strike: Global Offensive     0.200000
# Apex Legends™                        0.300000
# Forza Horizon 5                      0.300000
# Call of Duty®                        0.250000
# ...                                       ...
# Call of Duty®: Warzone™              0.350000
# Their Land                           1.000000
# Call of Duty®: Modern Warfare® II    0.250000
# SteamVR                              0.100000
# Resident Evil 4 Chainsaw Demo        0.273861
#
# Title                              Call of Duty®: Modern Warfare® II  SteamVR  \
# Title
# Baldur's Gate 3                                             0.200000      0.0
# Counter-Strike: Global Offensive                            0.500000      0.0
# Apex Legends™                                               0.350000      0.0
# Forza Horizon 5                                             0.450000      0.1
# Call of Duty®                                               0.850000      0.0
# ...                                                              ...      ...
# Call of Duty®: Warzone™                                     0.700000      0.0
# Their Land                                                  0.250000      0.1
# Call of Duty®: Modern Warfare® II                           1.000000      0.0
# SteamVR                                                     0.000000      1.0
# Resident Evil 4 Chainsaw Demo                               0.091287      0.0
#
# Title                              Resident Evil 4 Chainsaw Demo
# Title
# Baldur's Gate 3                                         0.091287
# Counter-Strike: Global Offensive                        0.091287
# Apex Legends™                                           0.182574
# Forza Horizon 5                                         0.182574
# Call of Duty®                                           0.182574
# ...                                                          ...
# Call of Duty®: Warzone™                                 0.273861
# Their Land                                              0.273861
# Call of Duty®: Modern Warfare® II                       0.091287
# SteamVR                                                 0.000000
# Resident Evil 4 Chainsaw Demo                           1.000000
#
# [5371 rows x 5371 columns]

# %% [markdown]
# # Game Description Similarity Matrix

# %%
# Get recommendations by game description
tfidf = TfidfVectorizer(stop_words="english")
games_df['Game Description'] = games_df['Game Description'].fillna("")
tfidf_matrix = tfidf.fit_transform(games_df['Game Description'])

# %%
desc_similarity = cosine_similarity(tfidf_matrix)
df_desc_similarity = pd.DataFrame(desc_similarity, columns=games_df['Title'], index=games_df['Title']);
display(df_desc_similarity)
# Out:
# Title                              Baldur's Gate 3  \
# Title
# Baldur's Gate 3                           1.000000
# Counter-Strike: Global Offensive          0.011879
# Apex Legends™                             0.000000
# Forza Horizon 5                           0.000000
# Call of Duty®                             0.000000
# ...                                            ...
# Call of Duty®: Warzone™                   0.000000
# Their Land                                0.016413
# Call of Duty®: Modern Warfare® II         0.000000
# SteamVR                                   0.000000
# Resident Evil 4 Chainsaw Demo             0.019236
#
# Title                              Counter-Strike: Global Offensive  \
# Title
# Baldur's Gate 3                                            0.011879
# Counter-Strike: Global Offensive                           1.000000
# Apex Legends™                                              0.031633
# Forza Horizon 5                                            0.008580
# Call of Duty®                                              0.000000
# ...                                                             ...
# Call of Duty®: Warzone™                                    0.035851
# Their Land                                                 0.060391
# Call of Duty®: Modern Warfare® II                          0.055060
# SteamVR                                                    0.000000
# Resident Evil 4 Chainsaw Demo                              0.006750
#
# Title                              Apex Legends™  Forza Horizon 5  \
# Title
# Baldur's Gate 3                         0.000000         0.000000
# Counter-Strike: Global Offensive        0.031633         0.008580
# Apex Legends™                           1.000000         0.009066
# Forza Horizon 5                         0.009066         1.000000
# Call of Duty®                           0.000000         0.000000
# ...                                          ...              ...
# Call of Duty®: Warzone™                 0.059600         0.000000
# Their Land                              0.035139         0.028657
# Call of Duty®: Modern Warfare® II       0.000000         0.000000
# SteamVR                                 0.020626         0.000000
# Resident Evil 4 Chainsaw Demo           0.011877         0.015343
#
# Title                              Call of Duty®  PUBG: BATTLEGROUNDS  \
# Title
# Baldur's Gate 3                         0.000000             0.000000
# Counter-Strike: Global Offensive        0.000000             0.021394
# Apex Legends™                           0.000000             0.133719
# Forza Horizon 5                         0.000000             0.006426
# Call of Duty®                           1.000000             0.000000
# ...                                          ...                  ...
# Call of Duty®: Warzone™                 0.148785             0.030728
# Their Land                              0.000000             0.035303
# Call of Duty®: Modern Warfare® II       0.363556             0.000000
# SteamVR                                 0.000000             0.007310
# Resident Evil 4 Chainsaw Demo           0.000000             0.024887
#
# Title                              Cyberpunk 2077     Rust  \
# Title
# Baldur's Gate 3                          0.068427  0.00000
# Counter-Strike: Global Offensive         0.009158  0.00000
# Apex Legends™                            0.000000  0.00000
# Forza Horizon 5                          0.045037  0.00000
# Call of Duty®                            0.000000  0.00000
# ...                                           ...      ...
# Call of Duty®: Warzone™                  0.000000  0.00000
# Their Land                               0.024636  0.03746
# Call of Duty®: Modern Warfare® II        0.000000  0.00000
# SteamVR                                  0.000000  0.00000
# Resident Evil 4 Chainsaw Demo            0.000000  0.00000
#
# Title                              Grand Theft Auto V  \
# Title
# Baldur's Gate 3                              0.000000
# Counter-Strike: Global Offensive             0.003424
# Apex Legends™                                0.058295
# Forza Horizon 5                              0.030851
# Call of Duty®                                0.000000
# ...                                               ...
# Call of Duty®: Warzone™                      0.000000
# Their Land                                   0.016621
# Call of Duty®: Modern Warfare® II            0.017162
# SteamVR                                      0.000000
# Resident Evil 4 Chainsaw Demo                0.020392
#
# Title                              Tom Clancy's Rainbow Six® Siege  ...  \
# Title                                                               ...
# Baldur's Gate 3                                           0.020796  ...
# Counter-Strike: Global Offensive                          0.033407  ...
# Apex Legends™                                             0.044224  ...
# Forza Horizon 5                                           0.000000  ...
# Call of Duty®                                             0.000000  ...
# ...                                                            ...  ...
# Call of Duty®: Warzone™                                   0.000000  ...
# Their Land                                                0.000000  ...
# Call of Duty®: Modern Warfare® II                         0.000000  ...
# SteamVR                                                   0.000000  ...
# Resident Evil 4 Chainsaw Demo                             0.000000  ...
#
# Title                              VERGE:Lost chapter  Resident Evil Re:Verse  \
# Title
# Baldur's Gate 3                              0.000000                0.000000
# Counter-Strike: Global Offensive             0.000000                0.024503
# Apex Legends™                                0.077578                0.033358
# Forza Horizon 5                              0.000000                0.000000
# Call of Duty®                                0.000000                0.000000
# ...                                               ...                     ...
# Call of Duty®: Warzone™                      0.000000                0.000000
# Their Land                                   0.000000                0.025393
# Call of Duty®: Modern Warfare® II            0.000000                0.027645
# SteamVR                                      0.000000                0.000000
# Resident Evil 4 Chainsaw Demo                0.000000                0.113214
#
# Title                              HAWKEN REBORN  100 hidden cups  \
# Title
# Baldur's Gate 3                         0.000000         0.000000
# Counter-Strike: Global Offensive        0.010514         0.000000
# Apex Legends™                           0.041398         0.000000
# Forza Horizon 5                         0.045600         0.014675
# Call of Duty®                           0.000000         0.000000
# ...                                          ...              ...
# Call of Duty®: Warzone™                 0.129441         0.000000
# Their Land                              0.015951         0.020041
# Call of Duty®: Modern Warfare® II       0.037182         0.000000
# SteamVR                                 0.010175         0.000000
# Resident Evil 4 Chainsaw Demo           0.009066         0.000000
#
# Title                              O2Jam Online  Call of Duty®: Warzone™  \
# Title
# Baldur's Gate 3                        0.000000                 0.000000
# Counter-Strike: Global Offensive       0.013480                 0.035851
# Apex Legends™                          0.028941                 0.059600
# Forza Horizon 5                        0.004436                 0.000000
# Call of Duty®                          0.000000                 0.148785
# ...                                         ...                      ...
# Call of Duty®: Warzone™                0.037969                 1.000000
# Their Land                             0.020451                 0.016163
# Call of Duty®: Modern Warfare® II      0.052840                 0.042028
# SteamVR                                0.013045                 0.014648
# Resident Evil 4 Chainsaw Demo          0.011623                 0.000000
#
# Title                              Their Land  \
# Title
# Baldur's Gate 3                      0.016413
# Counter-Strike: Global Offensive     0.060391
# Apex Legends™                        0.035139
# Forza Horizon 5                      0.028657
# Call of Duty®                        0.000000
# ...                                       ...
# Call of Duty®: Warzone™              0.016163
# Their Land                           1.000000
# Call of Duty®: Modern Warfare® II    0.000000
# SteamVR                              0.010258
# Resident Evil 4 Chainsaw Demo        0.020954
#
# Title                              Call of Duty®: Modern Warfare® II  \
# Title
# Baldur's Gate 3                                             0.000000
# Counter-Strike: Global Offensive                            0.055060
# Apex Legends™                                               0.000000
# Forza Horizon 5                                             0.000000
# Call of Duty®                                               0.363556
# ...                                                              ...
# Call of Duty®: Warzone™                                     0.042028
# Their Land                                                  0.000000
# Call of Duty®: Modern Warfare® II                           1.000000
# SteamVR                                                     0.000000
# Resident Evil 4 Chainsaw Demo                               0.000000
#
# Title                               SteamVR  Resident Evil 4 Chainsaw Demo
# Title
# Baldur's Gate 3                    0.000000                       0.019236
# Counter-Strike: Global Offensive   0.000000                       0.006750
# Apex Legends™                      0.020626                       0.011877
# Forza Horizon 5                    0.000000                       0.015343
# Call of Duty®                      0.000000                       0.000000
# ...                                     ...                            ...
# Call of Duty®: Warzone™            0.014648                       0.000000
# Their Land                         0.010258                       0.020954
# Call of Duty®: Modern Warfare® II  0.000000                       0.000000
# SteamVR                            1.000000                       0.000000
# Resident Evil 4 Chainsaw Demo      0.000000                       1.000000
#
# [5371 rows x 5371 columns]

# %% [markdown]
# # Recommend Game

# %%
def recommend_games(game_name, similarity_matrix, top_n=5):
    game_idx = list(game_genre_df.index).index(game_name)
    similarity_scores = similarity_matrix[game_idx]
    similarity_scores = similarity_scores.argsort()
    similar_games_idx = similarity_scores[-top_n-1:-1][::-1]
    for index, rec in enumerate([game_genre_df.index[i] for i in similar_games_idx]):
      print(f"Game {index+1}: {rec}")
      games_df.index = games_df['Title']
      # print(f"\t{games_df.loc[rec,'Game Description']}\n")

# %%
# favorite_game = "Slay the Spire" # Test game
favorite_game = input("What's your favorite game? ")
try:
  print("\nSteam recommendation by popular tags")
  recommendations = recommend_games(favorite_game, tag_similarity, 5)
  print("\nSteam recommendation by game description")
  recommendations = recommend_games(favorite_game, desc_similarity, 5)
except ValueError:
  print("That game is not in our list!")
# Out:
# What's your favorite game? Forza Horizon 5
#
# Steam recommendation by popular tags
# Game 1: Forza Horizon 4
# Game 2: Need For Speed: Hot Pursuit
# Game 3: The Crew™ 2
# Game 4: Need for Speed™ Heat
# Game 5: Need for Speed™ Rivals
#
# Steam recommendation by game description
# Game 1: Catto Pew Pew!
# Game 2: Portal
# Game 3: Death Horizon: Reloaded
# Game 4: Motor Town: Behind The Wheel
# Game 5: Trailmakers

# %% [markdown]
# # Dataset Info

# %% [markdown]
# ## Display all game titles

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_colwidth', 500)
display(games_df['Game Description'])
# Out:
# Title
# Baldur's Gate 3                                                                                                       Baldur’s Gate 3 is a story-rich, party-based RPG set in the universe of Dungeons & Dragons, where your choices shape a tale of fellowship and betrayal, survival and sacrifice, and the lure of absolute power.
# Counter-Strike: Global Offensive                  Counter-Strike: Global Offensive (CS: GO) expands upon the team-based action gameplay that it pioneered when it was launched 19 years ago. CS: GO features new maps, characters, weapons, and game modes, and delivers updated versions of the classic CS content (de_dust2, etc.).
# Apex Legends™                            Apex Legends is the award-winning, free-to-play Hero Shooter from Respawn Entertainment. Master an ever-growing roster of legendary characters with powerful abilities, and experience strategic squad play and innovative gameplay in the next evolution of Hero Shooter and Battle Royale.
# Forza Horizon 5                      Your Ultimate Horizon Adventure awaits! Explore the vibrant open world landscapes of Mexico with limitless, fun driving action in the world’s greatest cars. Conquer the rugged Sierra Nueva in the ultimate Horizon Rally experience. Requires Forza Horizon 5 game, expansion sold separately.
# Call of Duty®                                                                                                                                                                                            Welcome to Call of Duty® HQ, the home of Call of Duty®: Modern Warfare® III, Call of Duty®: Modern Warfare® II and Warzone™.
#                                                                                                                                                                                    ...
# Call of Duty®: Warzone™                                                                                                                                                                                                   Welcome to Warzone™, the massive free-to-play combat arena which now features the brand-new map, Al Mazrah.
# Their Land                                      Their Land is an action-adventure first-person game with puzzles and an exciting story to experience. You play Jeremy, a 19 year old orphan who explores an untrodden island with his much older and more experienced friends. Will you fall victim to this fabled lands many perils?
# Call of Duty®: Modern Warfare® II                                                                                                                                           Call of Duty®: Modern Warfare® II drops players into an unprecedented global conflict that features the return of the iconic Operators of Task Force 141.
# SteamVR                                                                                                                                                                  Grab SteamVR to access and play VR games using your HTC Vive, Oculus Rift, Windows Mixed Reality headset, or any other supported VR headset and controllers.
# Resident Evil 4 Chainsaw Demo                                      Survival is just the beginning. Experience a taste of Resident Evil 4, a reimagining of the original game released in 2005. This demo consists of a specially tuned version of the game's opening sequence and can be played repeatedly without time restrictions.
# Name: Game Description, Length: 5371, dtype: object

# %% [markdown]
# ## Display all steam tags

# %%
# pd.set_option('display.max_rows', None)
pd.set_option('display.max_rows', 10)
display(all_genres)
# Out:
#                            Tags
# 0                         'RPG'
# 1              'Choices Matter'
# 2     'Character Customization'
# 3                  'Story Rich'
# 4                   'Adventure'
# ..                          ...
# 727                   'Sokoban'
# 728             'Philosophical'
# 729                  'Cartoony'
# 730               'Underground'
# 731            'Web Publishing'
#
# [732 rows x 1 columns]

# %% [markdown]
# # Accuracy

# %%
# List of actual scores
actual_scores = [1, 0, 1, 0, 1]

# Predicted scores
def get_predictions(game_name, similarity_matrix, top_n=5):
    game_idx = list(game_genre_df.index).index(game_name)
    similarity_scores = similarity_matrix[game_idx]
    top_similarities = np.sort(similarity_scores)[-top_n:]
    return list(top_similarities[::-1])

# %%
# Evaluation of Popular Tags
print("\nEvaluation of Popular Tags")
predicted_scores_tags = get_predictions(favorite_game, tag_similarity, top_n=5)
true_relevance_tags = actual_scores[:len(predicted_scores_tags)]
mae_tags = mean_absolute_error(true_relevance_tags, predicted_scores_tags)
mse_tags = mean_squared_error(true_relevance_tags, predicted_scores_tags)
predicted_binary_tags = [1 if score >= 0.5 else 0 for score in predicted_scores_tags]
accuracy_tags = accuracy_score(true_relevance_tags, predicted_binary_tags)

print(f"MAE: {mae_tags}")
print(f"MSE: {mse_tags}")
print(f"Accuracy: {accuracy_tags}")
# Out:
# Evaluation of Popular Tags
# MAE: 0.43000000000000005
# MSE: 0.2985
# Accuracy: 0.6

# %%
# Evaluation of Game Descriptions
print("\nEvaluation of Game Descriptions")
predicted_scores_desc = get_predictions(favorite_game, desc_similarity, top_n=5)
true_relevance_desc = actual_scores[:len(predicted_scores_desc)]
mae_desc = mean_absolute_error(true_relevance_desc, predicted_scores_desc)
mse_desc = mean_squared_error(true_relevance_desc, predicted_scores_desc)
predicted_binary_desc = [1 if score >= 0.5 else 0 for score in predicted_scores_desc]
accuracy_desc = accuracy_score(true_relevance_desc, predicted_binary_desc)

print(f"MAE: {mae_desc}")
print(f"MSE: {mse_desc}")
print(f"Accuracy: {accuracy_desc}")
# Out:
# Evaluation of Game Descriptions
# MAE: 0.4069225153623509
# MSE: 0.2842923829200349
# Accuracy: 0.6
